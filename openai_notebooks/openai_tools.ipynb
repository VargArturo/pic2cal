# %%
import numpy as np
import json
# import matplotlib.pyplot as plt
from rec2cal.data_paths import rep_json, data_path
from rec2cal.utils import write_csv

from rec2cal.openai_api import format_data, get_calories, get_calories_for_datset


import openai

our_model = "ada:ft-personal-2022-12-25-20-56-27"
openai.api_key = "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"

recipies = json.load(open(rep_json, "rb"))

training  = format_data(recipies, "train")
validation  = format_data(recipies, "test")

# %%
 openai.Completion.create
# Out:
# <bound method Completion.create of <class 'openai.api_resources.completion.Completion'>>

# %%
openai.api_key
# Out:
# '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'

# %%
# import openai

# %%
print(validation[10]['prompt'],validation[10]['completion'])
# Out:
# Given the following recipe find the total calories using the following procedure:
# 1.go through the list of ingredients and identify what each ingredient is one by one
# 2.go through the instructions and identify the cooking method for each ingredient
# 3.read through the ingredients once more and using their quantites and the identified cooking method for each find the calories for each ingredient
# 4.Add all the calories for each ingredient to return the total calories of the dish
#
# Ingredients:
# 12 cup of butter-without salt, 1 1/2 pound of chicken-broiler or fryers-breast-skinless-boneless-meat only-raw, 12 pound of mushrooms-white-raw, 6 tablespoon of wheat flour-white-all-purpose-unenriched, 1 teaspoon of salt-table, 14 teaspoon of spices-pepper-black, 14 ounce of soup-chicken broth or bouillon-dry, 1 cup of cream-fluid-heavy whipping, 9 ounce of peas-green-frozen-unprepared, 2 ounce of spices-pepper-black.
#
# Instructions:
# In a large skillet, melt 2 tablespoons butter over medium-high heat. Saute the chicken and mushrooms for 5-6 minutes, or until no pink remains in the chicken. Remove the chicken and mushrooms from the skillet; discard the pan juices. Add the remaining butter, flour, salt, and pepper to the skillet; cook, whisking constantly, until the butter melts. Slowly add the chicken broth and cream; bring to a boil, whisking until smooth and thickened. Reduce the heat to medium-low, return the chicken and mushrooms to the skillet; add the peas and pimientos. Simmer until heated through, stirring constantly. Serve immediately.
#
# ###
#
#   total calories: 23659.054315

# %%
str_ = "\n".join(map(str,training)),

# %%
recipies = json.dump(training, open(data_path + "/open_ai_test.json", "w"))

# %%
write_csv(training, data_path, csv_name="/open_ai_simple_prompts_test.csv")

# %%
our_model = "ada:ft-personal-2022-12-25-20-56-27"

out_calories = get_calories_for_datset(our_model, validation)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1015.3750000000002 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016014,
#   "id": "cmpl-6ut3OqeTml7SugF2Nz964cis08cxm",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 296,
#     "total_tokens": 312
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 19411.65 end of code... End of the code alternative.\nEnd"
#     }
#   ],
#   "created": 1679016015,
#   "id": "cmpl-6ut3P4EOdTH2OXeTGDMyAEbfY5Adk",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 220,
#     "total_tokens": 236
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1519.75 end again. end . end . end . end . end"
#     }
#   ],
#   "created": 1679016015,
#   "id": "cmpl-6ut3PDI1U6MqxzYildNecHClBSdcj",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 442,
#     "total_tokens": 458
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 13419.0 end. end. end. end. end. end."
#     }
#   ],
#   "created": 1679016015,
#   "id": "cmpl-6ut3PQw6qeKE1SdmDDZrJp4C8P2oY",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 231,
#     "total_tokens": 247
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1828.0 end: end: end: end: end: end:"
#     }
#   ],
#   "created": 1679016015,
#   "id": "cmpl-6ut3PI6io3fbfHI7LduTbs9otV9cU",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 235,
#     "total_tokens": 251
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 3715.4416599999995 end end end end end end end end"
#     }
#   ],
#   "created": 1679016016,
#   "id": "cmpl-6ut3QL92Z2ukYmeZqv3UlvIIprfPs",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 240,
#     "total_tokens": 256
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 7281.000000000001 end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016016,
#   "id": "cmpl-6ut3QxyME4Y1UncKi8P4Cc2YIAMBh",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 323,
#     "total_tokens": 339
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1477.8125 end of end end end end end end end end end"
#     }
#   ],
#   "created": 1679016016,
#   "id": "cmpl-6ut3QD1DDNf7x1LV7C7B1jykFpmAv",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 444,
#     "total_tokens": 460
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 17811.0 end end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016017,
#   "id": "cmpl-6ut3Rd2Fk3us9dc5gC25zNXcqNFQm",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 302,
#     "total_tokens": 318
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2513.3541666666665 end.000000000000 end end end end"
#     }
#   ],
#   "created": 1679016017,
#   "id": "cmpl-6ut3Rr87EpSCsA4V2NZv4Wa5uTkk3",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 379,
#     "total_tokens": 395
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 10648.444475baum089840005 end . . end end"
#     }
#   ],
#   "created": 1679016017,
#   "id": "cmpl-6ut3RcrPyzmeoy8DOlfXvATcHQtk1",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 367,
#     "total_tokens": 383
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 13717.999999999999 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016017,
#   "id": "cmpl-6ut3RHSnz9fkgUuIouBJ1AWZlYYsU",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 267,
#     "total_tokens": 283
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2854.7500000000002 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016018,
#   "id": "cmpl-6ut3SXfLHtqr2iSzBZtiVEYa6rBrE",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 232,
#     "total_tokens": 248
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 311.00000000000006 end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016018,
#   "id": "cmpl-6ut3SRkaNT1APLc6wJeEmIWFBDLPw",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 261,
#     "total_tokens": 277
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 9459.999999999999 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016018,
#   "id": "cmpl-6ut3Sa9PzsPZAbykGwCSHc7OCosPZ",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 268,
#     "total_tokens": 284
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 288.0 end. end. end. end. end. end. end"
#     }
#   ],
#   "created": 1679016019,
#   "id": "cmpl-6ut3TgvUfMRPT1Xp3dhPnC0892gWG",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 505,
#     "total_tokens": 521
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 122784.7552 end point set to 0 end of dishes end of"
#     }
#   ],
#   "created": 1679016019,
#   "id": "cmpl-6ut3TWVhvUQyh9uRWoZRS3jKob35W",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 282,
#     "total_tokens": 298
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2004.9064 endiany-non Jessie Pallet (30489)"
#     }
#   ],
#   "created": 1679016019,
#   "id": "cmpl-6ut3TtivDTAW29FAjrUrVhXRCdWYa",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 341,
#     "total_tokens": 357
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 10152.636266666664 end size end size end size end"
#     }
#   ],
#   "created": 1679016020,
#   "id": "cmpl-6ut3U1qrvI4OdVNrciE9uIofSC5tl",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 474,
#     "total_tokens": 490
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 881.4999999999999 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016020,
#   "id": "cmpl-6ut3USS1kMzwxb5SybvXhSBY9bkcA",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 241,
#     "total_tokens": 257
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2267.8104 endy n match rst position getMetaData r"
#     }
#   ],
#   "created": 1679016020,
#   "id": "cmpl-6ut3UuSto1AGq08OL2ROcGcgIrt7X",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 258,
#     "total_tokens": 274
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1230.75 end. end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016020,
#   "id": "cmpl-6ut3UomnlmqU97Jdwcdy7xXPood9v",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 193,
#     "total_tokens": 209
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2482.0032571428573 end end end end end end end end"
#     }
#   ],
#   "created": 1679016021,
#   "id": "cmpl-6ut3V7lrzlW0IeZbJobICjrmOoQHy",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 298,
#     "total_tokens": 314
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 19555.8532 endnotes find the calculations using the below procedure:\n"
#     }
#   ],
#   "created": 1679016021,
#   "id": "cmpl-6ut3VdskfXFSzs17OeD4cLktPW14a",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 243,
#     "total_tokens": 259
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 170.0 end end end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016021,
#   "id": "cmpl-6ut3VLBhh8HhdpeIZ9CWUSXHR1Fsr",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 213,
#     "total_tokens": 229
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2515.0 end of WARNING: Re-baseline calories: totally wrong"
#     }
#   ],
#   "created": 1679016022,
#   "id": "cmpl-6ut3WqCj03tnlLvQam0N9RTG1FSPR",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 282,
#     "total_tokens": 298
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 803.17600000000001 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016022,
#   "id": "cmpl-6ut3WniJ69nVxgPpEUABnvOkAlpQi",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 214,
#     "total_tokens": 230
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 11337.016406666666 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016022,
#   "id": "cmpl-6ut3WMZpc5sl7VJ60wtqITRZwiZL6",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 572,
#     "total_tokens": 588
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1251.074930000001 endnotes. END\n\n endnotes. END"
#     }
#   ],
#   "created": 1679016022,
#   "id": "cmpl-6ut3Wy5vXa49MwCuK7Bvt6Dun6BRK",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 530,
#     "total_tokens": 546
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1041.9999999999998 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016023,
#   "id": "cmpl-6ut3X3zLgz859zaUIwk5OKXVlW0ek",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 191,
#     "total_tokens": 207
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 3186.0 end point; 1.0 end point; end points of"
#     }
#   ],
#   "created": 1679016023,
#   "id": "cmpl-6ut3XPJQnfssA8xQb9Kt1Ob9IGKKc",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 270,
#     "total_tokens": 286
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2846.0 end of article. (0) end of session. end"
#     }
#   ],
#   "created": 1679016023,
#   "id": "cmpl-6ut3XhZVqjRdS1PrrR2QpWyttIdZn",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 272,
#     "total_tokens": 288
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 14419.764639999999 end of table end of page end of"
#     }
#   ],
#   "created": 1679016024,
#   "id": "cmpl-6ut3Y03VRdmdAr7xW8UnrrjnJmXad",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 256,
#     "total_tokens": 272
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 511.801200000002 end end score end end end final score end"
#     }
#   ],
#   "created": 1679016024,
#   "id": "cmpl-6ut3Y6MLcBx6UrkWGs7xvzO6LIvJ5",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 248,
#     "total_tokens": 264
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 287.0 end_beets_raw_136.0 end_grain"
#     }
#   ],
#   "created": 1679016024,
#   "id": "cmpl-6ut3Ybc9BwAztwPnok9KJQaTEPMms",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 368,
#     "total_tokens": 384
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 11891.625 end of end end end end end end end end end"
#     }
#   ],
#   "created": 1679016024,
#   "id": "cmpl-6ut3Y9aHlZSqgdQFTVPZyW473o2Zt",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 203,
#     "total_tokens": 219
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 13440.685714285712 end of recipe request end of see"
#     }
#   ],
#   "created": 1679016025,
#   "id": "cmpl-6ut3ZiG121SYzSWRCLrD06K0o1zOR",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 192,
#     "total_tokens": 208
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 21288.0 end of 2014.0 end of 2015.0 end of"
#     }
#   ],
#   "created": 1679016025,
#   "id": "cmpl-6ut3ZPcU3hNhrODDW24jufyWpEBsw",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 278,
#     "total_tokens": 294
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1040.060428 lod 0 end end end end end end end end"
#     }
#   ],
#   "created": 1679016025,
#   "id": "cmpl-6ut3ZUIZOQY6kaJnKtoMI4aD20xcq",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 219,
#     "total_tokens": 235
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " 6667.148 end of page.\n\n\n\n\nNext"
#     }
#   ],
#   "created": 1679016025,
#   "id": "cmpl-6ut3ZD7UeeKexKLoXd1HnmZBWAgkY",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 12,
#     "prompt_tokens": 216,
#     "total_tokens": 228
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 12638.0 end end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016026,
#   "id": "cmpl-6ut3ale7EcTkxQyFEVAiCLBL9o8re",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 254,
#     "total_tokens": 270
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 774.37367 endo.eth@noordoever.net"
#     }
#   ],
#   "created": 1679016026,
#   "id": "cmpl-6ut3aovvjNgsnwvn7ih5tRmIEnH4A",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 155,
#     "total_tokens": 171
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 15831.0 end\n\n 11638.249999999998 end\n###"
#     }
#   ],
#   "created": 1679016026,
#   "id": "cmpl-6ut3aG3VUPuuv7BNUH892g5Vp2bfr",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 318,
#     "total_tokens": 334
#   }
# }
# Done with 43 prompts
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 687.2700999999999 end end end end end end end end"
#     }
#   ],
#   "created": 1679016087,
#   "id": "cmpl-6ut4ZPY9RDANx6EhDgITOgE26wmx4",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 241,
#     "total_tokens": 257
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 18246.47576 end-of-year 2006-07-30 end"
#     }
#   ],
#   "created": 1679016087,
#   "id": "cmpl-6ut4Z3yiUZfrYMGcaV7YinvL8qm8M",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 249,
#     "total_tokens": 265
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1952.47850666666666 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016087,
#   "id": "cmpl-6ut4ZvIMn7T7ICes0CyWZs5ICrWj4",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 212,
#     "total_tokens": 228
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 12780.4572 end about 4 hours ago. end about 4 hours ago"
#     }
#   ],
#   "created": 1679016087,
#   "id": "cmpl-6ut4ZNVBWR9jMSOml2O0TBnQUHBON",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 290,
#     "total_tokens": 306
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1583.25 end: end: end: end: end: end:"
#     }
#   ],
#   "created": 1679016088,
#   "id": "cmpl-6ut4a13ZOEMAQVEPFdaiRCBnBkjDB",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 204,
#     "total_tokens": 220
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 13827.25 end up with a meatball sauce with an increased number of"
#     }
#   ],
#   "created": 1679016088,
#   "id": "cmpl-6ut4aQ5fa6olz8dzXm5XIrd7EBoxs",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 188,
#     "total_tokens": 204
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 177.0 end of this article.\n\n end of this article. end of"
#     }
#   ],
#   "created": 1679016088,
#   "id": "cmpl-6ut4aMuCx89ReTFS2pX67xN6xTQz2",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 252,
#     "total_tokens": 268
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 22206.0 end. end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016088,
#   "id": "cmpl-6ut4aXPmPhY1EXufou1PgyqvhT0gk",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 256,
#     "total_tokens": 272
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1973.24495799999997 end mast receiver endstacking end transmitting"
#     }
#   ],
#   "created": 1679016089,
#   "id": "cmpl-6ut4b7yhFEELvcubh7yUBoYl21Wwd",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 181,
#     "total_tokens": 197
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1173.92159 end of the line end of the country end of the"
#     }
#   ],
#   "created": 1679016089,
#   "id": "cmpl-6ut4bmOKZ2uB1fRS6fDdrbDiMwcqD",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 284,
#     "total_tokens": 300
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1949.7348099999998 end end end end end end end end"
#     }
#   ],
#   "created": 1679016089,
#   "id": "cmpl-6ut4bLqmU7gAf3SkQOzxLr7E3PA8M",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 238,
#     "total_tokens": 254
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 266.54289 end of process.\n###\n\n 519.9108"
#     }
#   ],
#   "created": 1679016090,
#   "id": "cmpl-6ut4cUxr17orTdQ4zWq8utmTYCZaW",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 243,
#     "total_tokens": 259
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 885.523535714 28991.35714285714"
#     }
#   ],
#   "created": 1679016090,
#   "id": "cmpl-6ut4cql6BrHJtZ6v0A2nBTDfDqEm8",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 297,
#     "total_tokens": 313
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 555.0759399999999 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016090,
#   "id": "cmpl-6ut4cRsnIVm1x60zuApMiSFfbXTsf",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 237,
#     "total_tokens": 253
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 14223.953393333333 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016091,
#   "id": "cmpl-6ut4dOqFNGFUCesNWe4MRiJcvvvCq",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 288,
#     "total_tokens": 304
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 11340.000000000002 end of the cb-ss-webdoc sub"
#     }
#   ],
#   "created": 1679016091,
#   "id": "cmpl-6ut4deMY0bFwZYQnQybwrNFG1t3bM",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 303,
#     "total_tokens": 319
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 13520.9678 end. end. end. end. end. end"
#     }
#   ],
#   "created": 1679016091,
#   "id": "cmpl-6ut4dlBEscSJxtqlwnnfxlqRNQne8",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 285,
#     "total_tokens": 301
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2050.78524 endgame.1693999999998 endgame.127"
#     }
#   ],
#   "created": 1679016092,
#   "id": "cmpl-6ut4e1khULMymZamNhINhsVAaZlVh",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 274,
#     "total_tokens": 290
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1414.6318208099709 end end end end end end end"
#     }
#   ],
#   "created": 1679016092,
#   "id": "cmpl-6ut4eRutyOBsFlhhWVg3vhtYWV54p",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 298,
#     "total_tokens": 314
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 811.8546 end file end . . . . . . . ."
#     }
#   ],
#   "created": 1679016092,
#   "id": "cmpl-6ut4eui1T75CpOApfBJt1nb7SgTaP",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 435,
#     "total_tokens": 451
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 15086.743740000002 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016092,
#   "id": "cmpl-6ut4eZfP4lMl4csADMSps0OE4hSJR",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 411,
#     "total_tokens": 427
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 9514.9375 end of analysis end of paper\n###\n\n 11977"
#     }
#   ],
#   "created": 1679016093,
#   "id": "cmpl-6ut4fIiQAKz4t8RlSEysui140G8k1",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 280,
#     "total_tokens": 296
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1432.802335 end-product end-price end-exact"
#     }
#   ],
#   "created": 1679016093,
#   "id": "cmpl-6ut4fhDn7OTi8gnZ6krm72zh1OU7v",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 252,
#     "total_tokens": 268
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 212.4836 end of comment section.\n\n end of loop (24 survivors"
#     }
#   ],
#   "created": 1679016093,
#   "id": "cmpl-6ut4fXb7V3pxGPddD6QhNJq3SLrxd",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 173,
#     "total_tokens": 189
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2016.62608 endup.0 endup endup endup endup"
#     }
#   ],
#   "created": 1679016093,
#   "id": "cmpl-6ut4fIHnhjK8lChA7mOBbkXuFFkCZ",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 286,
#     "total_tokens": 302
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 13750.10704 endymion current author and publisher account of endym"
#     }
#   ],
#   "created": 1679016094,
#   "id": "cmpl-6ut4gQ70BT5BQasvawW9CKnucr1rk",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 264,
#     "total_tokens": 280
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 4146.0427 end of lunch menu.\n\n end of menu.\n"
#     }
#   ],
#   "created": 1679016094,
#   "id": "cmpl-6ut4gGNlbeD3JjtBDdDqWXL8aunxp",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 341,
#     "total_tokens": 357
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1677.5000000000001 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016094,
#   "id": "cmpl-6ut4gkiPw2ZKp6oeydANowHXVqSsK",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 343,
#     "total_tokens": 359
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 4815.999999999999 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016095,
#   "id": "cmpl-6ut4hUjYuul1lbT8k2CazpVRAIYzK",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 255,
#     "total_tokens": 271
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1388.61928 end. end. end. end. end."
#     }
#   ],
#   "created": 1679016095,
#   "id": "cmpl-6ut4heMzMGIrqq2UcaJnNJbT2Bet9",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 332,
#     "total_tokens": 348
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 9333.78712 end.000000 end.000000 end.000000 end end"
#     }
#   ],
#   "created": 1679016095,
#   "id": "cmpl-6ut4hcZyppod71lkqLFE160LVt127",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 157,
#     "total_tokens": 173
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 5038.0 end % end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016095,
#   "id": "cmpl-6ut4hg1pqYaQRJnrGHhhhGc7FPusV",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 172,
#     "total_tokens": 188
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1271.2421999999999 end of line end of sentence end of paragraph"
#     }
#   ],
#   "created": 1679016096,
#   "id": "cmpl-6ut4itzZjLaodpQ7a7Ziu0JIbF8iN",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 246,
#     "total_tokens": 262
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 651.875 endpoints endpoints endpoints endpoints endpoints endpoints"
#     }
#   ],
#   "created": 1679016096,
#   "id": "cmpl-6ut4iEK08ToxpF3QqW7jbntuiXDUG",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 162,
#     "total_tokens": 178
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 5197.8074857142855 end end end end end end end"
#     }
#   ],
#   "created": 1679016096,
#   "id": "cmpl-6ut4iD5xW6ks9KiTPFtIVPGEHFK5x",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 267,
#     "total_tokens": 283
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 11088.118979999999 end 2 end end\n\n###\n\n"
#     }
#   ],
#   "created": 1679016097,
#   "id": "cmpl-6ut4j6N59vO5PVIvXR76q2zMbKhq4",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 286,
#     "total_tokens": 302
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1711.1575199999998 end _______________________ end end end end"
#     }
#   ],
#   "created": 1679016097,
#   "id": "cmpl-6ut4jwboTpnluiKccgQ2rhlzSTeF6",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 341,
#     "total_tokens": 357
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2884.2015 end of the worksheet end of the worksheet end of"
#     }
#   ],
#   "created": 1679016097,
#   "id": "cmpl-6ut4j9NMVFLpKmXGONKypRwc10DRN",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 172,
#     "total_tokens": 188
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 261.9991666666666 end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016098,
#   "id": "cmpl-6ut4ktecsaWA3fHv8MqUdIcg2onAv",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 408,
#     "total_tokens": 424
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2073.5 end the second half of the vacation and the second half of"
#     }
#   ],
#   "created": 1679016098,
#   "id": "cmpl-6ut4kFV5lWnDGuhWnuS5nqvGW5O6J",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 248,
#     "total_tokens": 264
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 178.3823201930706 end currentDate End of week Date--year"
#     }
#   ],
#   "created": 1679016098,
#   "id": "cmpl-6ut4ksZWfXeJ2t94uvCAJpZMT2jHg",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 149,
#     "total_tokens": 165
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 430.23912 end of list\n\n end of commentary\n###\n\n 256."
#     }
#   ],
#   "created": 1679016098,
#   "id": "cmpl-6ut4kJz5KPM1OCt5a9hpJ2PLBAm8h",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 341,
#     "total_tokens": 357
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 895.0 end. end. end. end. end. end."
#     }
#   ],
#   "created": 1679016099,
#   "id": "cmpl-6ut4lokai2qoTNU2D1vRHB9fAVCfi",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 200,
#     "total_tokens": 216
#   }
# }
# Done with 86 prompts
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 14876.5 end-overs=5 end-casts=0 end-"
#     }
#   ],
#   "created": 1679016159,
#   "id": "cmpl-6ut5jxKtuERHhZuHtBc47fXxQIOfh",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 195,
#     "total_tokens": 211
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2734.6250000000003 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016159,
#   "id": "cmpl-6ut5jGFBjH2EKdMkfABuJCY1udopa",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 249,
#     "total_tokens": 265
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 14911.0 endall endarline endfeed endfeed endfeed end"
#     }
#   ],
#   "created": 1679016160,
#   "id": "cmpl-6ut5kkcXwN9oFRY4ko9dMxZ558Zaw",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 304,
#     "total_tokens": 320
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1778.5 end 0 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016160,
#   "id": "cmpl-6ut5k0deGKBbPNRV1xU98gjJG8r7q",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 697,
#     "total_tokens": 713
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1160.0 end end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016160,
#   "id": "cmpl-6ut5kdA0ywoCO1tWlVcHN0OY7jSeA",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 168,
#     "total_tokens": 184
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 17718.0 end end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016160,
#   "id": "cmpl-6ut5k1wjLfL0RORWnuB4pz5wBxLzu",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 242,
#     "total_tokens": 258
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 650.2193399999999 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016161,
#   "id": "cmpl-6ut5l47xo9xel7YwMWNDgIweddWlV",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 220,
#     "total_tokens": 236
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2126.0 end unspecified end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016161,
#   "id": "cmpl-6ut5ldYQf1kqfV2eGraYdMjtDvYwf",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 392,
#     "total_tokens": 408
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 590.9999999999999 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016161,
#   "id": "cmpl-6ut5lLsblil4oL0u8E8umcteDdKNQ",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 167,
#     "total_tokens": 183
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 274.04999999999996 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016162,
#   "id": "cmpl-6ut5m2rsturuw96GzodrfPFTyPd1c",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 165,
#     "total_tokens": 181
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 13431.999999999998 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016162,
#   "id": "cmpl-6ut5mQByRNboloxbTvHwmMeb3p8gv",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 337,
#     "total_tokens": 353
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2224. 2552.75 end the copyright notice end the copyright notice\n\n"
#     }
#   ],
#   "created": 1679016162,
#   "id": "cmpl-6ut5mp3JFErxqI8Qij3KMtvQNNq5q",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 269,
#     "total_tokens": 285
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1123.48639999999997 end end end end end end end end"
#     }
#   ],
#   "created": 1679016163,
#   "id": "cmpl-6ut5nR6UgKivsN9TrFzyQioAUvr7J",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 316,
#     "total_tokens": 332
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 15468.0 end recipes end\n\n 51855.0 end recipes end"
#     }
#   ],
#   "created": 1679016163,
#   "id": "cmpl-6ut5nOaqGEDprQYDhopKAYf3SDlGO",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 245,
#     "total_tokens": 261
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 470.0000000000001 end of examples end of . . . . . ."
#     }
#   ],
#   "created": 1679016164,
#   "id": "cmpl-6ut5oIvLhLzGpPOU95Ga0Oe1LGJpI",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 279,
#     "total_tokens": 295
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1576.0833333333335 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016164,
#   "id": "cmpl-6ut5oubxP1uFV80bsPzw74EleJXQ7",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 599,
#     "total_tokens": 615
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 506.0 end . . . end . . . end . . ."
#     }
#   ],
#   "created": 1679016164,
#   "id": "cmpl-6ut5oTqhr9iPcXyHi3bQCZxCs5cNh",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 169,
#     "total_tokens": 185
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 662.94999999999999 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016164,
#   "id": "cmpl-6ut5obzajS5E6ZOqGh9WuSGaS4GRf",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 258,
#     "total_tokens": 274
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 4956.5 endpoints=4000 endpoints=4000 endpoints=4000"
#     }
#   ],
#   "created": 1679016165,
#   "id": "cmpl-6ut5pRPr5s73gTCOqugL5LYvkWDGA",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 570,
#     "total_tokens": 586
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 791.8066226666666 end end end end end end end end"
#     }
#   ],
#   "created": 1679016165,
#   "id": "cmpl-6ut5pSbZ9ln06b6hbS3uSQhGEziy7",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 260,
#     "total_tokens": 276
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 363.0 end august 2026.0 end august 27.0"
#     }
#   ],
#   "created": 1679016165,
#   "id": "cmpl-6ut5pWJZL3JBPD2QccSa4oWp7Tvvu",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 445,
#     "total_tokens": 461
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1146.0 end: 0 end: 0 end: 0 end: 130"
#     }
#   ],
#   "created": 1679016166,
#   "id": "cmpl-6ut5qH2eAwlco8pk9pfS0LGq1CN9w",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 244,
#     "total_tokens": 260
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2599.0 end : end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016166,
#   "id": "cmpl-6ut5quyxP4O7LFsiG44UItGip84LB",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 478,
#     "total_tokens": 494
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 384.20242 endothermusca endothermusca endothermusca"
#     }
#   ],
#   "created": 1679016167,
#   "id": "cmpl-6ut5rixIk23fwN5CbeH4Z5p0Abm45",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 139,
#     "total_tokens": 155
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2160.0 end 0 end 0 end 0 end 0 end 0 end 0"
#     }
#   ],
#   "created": 1679016167,
#   "id": "cmpl-6ut5r133uuFUIJ8nGdg8Ak3O9tibz",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 193,
#     "total_tokens": 209
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 337.0736 end. end. end. end. end. end."
#     }
#   ],
#   "created": 1679016167,
#   "id": "cmpl-6ut5rnzpbXY6jsvP4HZ9X9fMlmNBW",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 166,
#     "total_tokens": 182
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
# ...
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 211,
#     "total_tokens": 227
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 6265.873375 end user style end user style end user style end"
#     }
#   ],
#   "created": 1679016235,
#   "id": "cmpl-6ut6xcgLVYWy5fYjtpPiPevBmShff",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 258,
#     "total_tokens": 274
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 4153.1 end of reserved space end of end of rind end of"
#     }
#   ],
#   "created": 1679016235,
#   "id": "cmpl-6ut6xMqZRWG2AvlLB4djjIGTvRp2w",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 264,
#     "total_tokens": 280
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 3244.0 end of article\n\n i.g. end of article\n\n"
#     }
#   ],
#   "created": 1679016235,
#   "id": "cmpl-6ut6xo3y9umccnet8ZFDsX2ncbQkK",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 225,
#     "total_tokens": 241
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 14903.00000000001920 end for 2017-04-01 to 2017-"
#     }
#   ],
#   "created": 1679016236,
#   "id": "cmpl-6ut6y5Gcf66oY4efm9bVP9kgiKJbA",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 288,
#     "total_tokens": 304
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 5960.0 end end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016236,
#   "id": "cmpl-6ut6yjviYSBnMhjeenEn4gJptzKox",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 231,
#     "total_tokens": 247
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 15208.30569 end 17055.5 end 18095."
#     }
#   ],
#   "created": 1679016236,
#   "id": "cmpl-6ut6y0fm9hGxUo8xYcP8uD3SGv1r2",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 518,
#     "total_tokens": 534
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1455.5 end of slow cooker chicken, rice, rice and rice is"
#     }
#   ],
#   "created": 1679016236,
#   "id": "cmpl-6ut6yeVFCGwi9wjm0eKjKJFNrxT6A",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 294,
#     "total_tokens": 310
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1373.0 end. end. end. end. end. end."
#     }
#   ],
#   "created": 1679016237,
#   "id": "cmpl-6ut6zbOsiBOMPAoPgl7DxHdZ4E7TS",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 223,
#     "total_tokens": 239
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 3756.0 end of article. end of story. end of chapter."
#     }
#   ],
#   "created": 1679016237,
#   "id": "cmpl-6ut6zczIiXwI4XR7FdntQpDCwOYCu",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 260,
#     "total_tokens": 276
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 7228.3576 end57 end67 end67 end67 end67 end"
#     }
#   ],
#   "created": 1679016237,
#   "id": "cmpl-6ut6zVLhNxyxqvcGV8t9Auns4v9OX",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 215,
#     "total_tokens": 231
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 7318.0 end Table Description-------------- end End of data frame end. end"
#     }
#   ],
#   "created": 1679016237,
#   "id": "cmpl-6ut6zxzD6CuKXYuWnswJRBCpeRZtx",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 304,
#     "total_tokens": 320
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 12217.500000000001 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016238,
#   "id": "cmpl-6ut70uw8p7dVkcachHKE37IC4SJJJ",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 465,
#     "total_tokens": 481
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2356.9999999999995 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016238,
#   "id": "cmpl-6ut70uLdHGxK5A8MIen3P55rxWCBH",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 195,
#     "total_tokens": 211
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 162.000000000000002 end\nEnd of nums\n###\n\n 221."
#     }
#   ],
#   "created": 1679016238,
#   "id": "cmpl-6ut70xTh4jBZDcwODRMHmmrXckVwt",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 172,
#     "total_tokens": 188
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 12345.1428571428573 end 2,139.06147"
#     }
#   ],
#   "created": 1679016239,
#   "id": "cmpl-6ut71L0L8cGT41i5MR3gIF3KBobra",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 189,
#     "total_tokens": 205
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 8662.125000000001 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016239,
#   "id": "cmpl-6ut71IfgktTkgapZSaZ1IMIXK9vbl",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 258,
#     "total_tokens": 274
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2012.6788999999998 end of season end of the season end of"
#     }
#   ],
#   "created": 1679016239,
#   "id": "cmpl-6ut713YNRv3AVjCavi2Xme0ei2kuW",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 271,
#     "total_tokens": 287
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 10046.75 end of line. end of line. end of line."
#     }
#   ],
#   "created": 1679016239,
#   "id": "cmpl-6ut71IlSk7ZYyQTOpeyemtnuvP0JO",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 203,
#     "total_tokens": 219
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 460.0 end. end. end. end. end. end.end"
#     }
#   ],
#   "created": 1679016240,
#   "id": "cmpl-6ut72rixWoXOZLT3RVBcFNLP16sfs",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 228,
#     "total_tokens": 244
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 360.9999999999999 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016240,
#   "id": "cmpl-6ut72tVcsn6NoUaQ4Bcv5XIce57GH",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 271,
#     "total_tokens": 287
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 715.9999999999998 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016240,
#   "id": "cmpl-6ut7244lbj3CvpTMPbcYdEL4RwXNY",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 269,
#     "total_tokens": 285
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1835.9505599999999 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016241,
#   "id": "cmpl-6ut73fHI7gHsrhWyCHxGAqE5KexE9",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 278,
#     "total_tokens": 294
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 483.75 end ticketing end ticketing end ticketing end ticketing"
#     }
#   ],
#   "created": 1679016241,
#   "id": "cmpl-6ut73l6HbzicYp8Cj6H9lLnWYdOF4",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 149,
#     "total_tokens": 165
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1794.307417000002 end end end end end end end of"
#     }
#   ],
#   "created": 1679016241,
#   "id": "cmpl-6ut73yNNpfiaAa9ud4kSnyOQ4QBf1",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 223,
#     "total_tokens": 239
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1576.9999999999998 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016241,
#   "id": "cmpl-6ut73kcMH2tXVW198YboScKxBXLBQ",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 243,
#     "total_tokens": 259
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 3726.3135 end oat pastry end room. end end end end"
#     }
#   ],
#   "created": 1679016242,
#   "id": "cmpl-6ut74QrtjtXyPpD6x6Q0KL4oIO1d9",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 271,
#     "total_tokens": 287
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2480.490650 end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016242,
#   "id": "cmpl-6ut74uLJw9qvNdktClQvMLnNoB0lC",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 229,
#     "total_tokens": 245
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 572.05 end. end. end. end. end. end."
#     }
#   ],
#   "created": 1679016242,
#   "id": "cmpl-6ut74R5ugSL2ZkdwxyMoinvX3x25D",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 348,
#     "total_tokens": 364
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 246.0 end of table end of article. end of table end of article"
#     }
#   ],
#   "created": 1679016242,
#   "id": "cmpl-6ut74a2zkh9EPwxqcAwNhcFpVFD43",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 261,
#     "total_tokens": 277
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 7478.564589045648 end end end end end end end end"
#     }
#   ],
#   "created": 1679016243,
#   "id": "cmpl-6ut75nqAWHAJdv0s4TPX8AhBHVv1J",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 370,
#     "total_tokens": 386
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 214.00000000000006 end end end end end end end end end end end"
#     }
#   ],
#   "created": 1679016243,
#   "id": "cmpl-6ut75LENDsVN8BWafxfT0CDYV0dmd",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 217,
#     "total_tokens": 233
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 21138.6875 end EU commission welcome response again. end end end end"
#     }
#   ],
#   "created": 1679016243,
#   "id": "cmpl-6ut757ZsUJqkhFA8k8JE4tr021IoW",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 228,
#     "total_tokens": 244
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1184.5 endivoegresa endivoegresa endivo"
#     }
#   ],
#   "created": 1679016243,
#   "id": "cmpl-6ut75Np1QGF10suwIbpM8Wdaz5uHR",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 215,
#     "total_tokens": 231
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2928.5369999999999 end end end end end end end end end"
#     }
#   ],
#   "created": 1679016244,
#   "id": "cmpl-6ut76hZaC0G32J89CHwNFBdnviieK",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 216,
#     "total_tokens": 232
#   }
# }
# Done with 172 prompts
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 2675.1358 end. end end end end end end end end end"
#     }
#   ],
#   "created": 1679016304,
#   "id": "cmpl-6ut84qszJutrsoJNsrfjZQ0LdcOUT",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 299,
#     "total_tokens": 315
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 1448.0000000000002 end\n###\n\n 1409.0000000000002"
#     }
#   ],
#   "created": 1679016304,
#   "id": "cmpl-6ut84fly79bby4SDbPQZAdkZwnRiz",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 222,
#     "total_tokens": 238
#   }
# }
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " 13755.500000000002 end go ahead and add carbs for your daily"
#     }
#   ],
#   "created": 1679016304,
#   "id": "cmpl-6ut846dLChAXoPksNdE0ygzbvJ2K6",
#   "model": "ada:ft-personal-2022-12-25-20-56-27",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 16,
#     "prompt_tokens": 301,
#     "total_tokens": 317
#   }
# }

# %%
out_calories
# Out:
# [674.75,
#  84586.0,
#  1624.352,
#  11523.249999999998,
#  2029.0000000000002,
#  5248.100640000001,
#  12342.0,
#  1456.9,
#  59463.0,
#  1592.4761875,
#  22302.710189999998,
#  17583.0,
#  2497.815,
#  99.0,
#  23582.0,
#  403.0,
#  63191.24584,
#  3466.3615199999995,
#  18613.19177,
#  1141.5,
#  2516.07012,
#  1531.3541666666667,
#  2703.0703285714285,
#  34310.33157999999,
#  32.5,
#  2830.0,
#  750.2488133333334,
#  18648.817933333332,
#  1537.2132487499998,
#  447.50000000000006,
#  4604.0,
#  3452.5,
#  18949.254559999998,
#  451.75007999999997,
#  484.3576,
#  27650.6875,
#  29386.285714285714,
#  66786.99999999999,
#  1742.4575526666667,
#  4927.34032,
#  21456.0,
#  1196.7836433333332,
#  19629.875,
#  423.2916666666667,
#  46845.07641,
#  2560.8605533333334,
#  41034.42908,
#  1724.475,
#  30798.499999999996,
#  95.5,
#  74843.0,
#  2539.11109,
#  1373.67143,
#  3526.7468,
#  58.79720000000001,
#  1015.4396125714286,
#  577.007280000001,
#  32716.77338666667,
#  28319.499999999996,
#  17167.04728,
#  2690.93289,
#  2318.903115933622,
#  837.95874,
#  13996.35962773456,
#  14486.1875,
#  2860.120162499,
#  24.326000000000004,
#  1889.894226666666,
#  37358.15982666664,
#  4081.69594,
#  2448.56,
#  5866.999999999999,
#  1571.04456,
#  34032.6532,
#  6740.0,
#  1687.84476,
#  227.62261867142854,
#  11544.80477142857,
#  19860.396399999998,
#  1098.9712066666666,
#  3301.15384,
#  2254.937500000001,
#  2879.3333333333335,
#  94.04309,
#  174.33888,
#  698.0,
#  27855.000000000004,
#  3862.625000000005,
#  28665.0,
#  1770.5,
#  1180.0,
#  34457.67,
#  564.63964,
#  5396.5,
#  976.0,
#  322.04166666666663,
#  31980.0,
#  1963.375,
#  1527.87288,
#  47578.99999999999,
#  165.5,
#  2949.166666666666,
#  132.5,
#  591.8124999999999,
#  4470.125,
#  707.40532,
#  1058.0,
#  1360.0000000000002,
#  2266.63,
#  405.74395,
#  2179.0,
#  794.5133599999999,
#  327.0,
#  26146.374999999996,
#  899.0559038672441,
#  2052.19488,
#  98.83333333333331,
#  1265.2000000000003,
#  540.8583333333333,
#  8691.22208,
#  37147.5,
#  27646.000000000004,
#  33773.0,
#  63462.875,
#  1679.5,
#  233.99999999999997,
#  26055.31492,
#  60.08333333333333,
#  1287.0,
#  41365.625,
#  1102.5,
#  35073.63374000001,
#  1685.98691,
#  3163.9717415511245,
#  829.2359200000002,
#  1094.03648,
#  5227.216992282844,
#  38027.0,
#  14611.703405,
#  7854.7,
#  4156.0,
#  30081.000000000004,
#  6895.0,
#  19137.049291666666,
#  2126.6813333333334,
#  3217.9999999999995,
#  1855.5,
#  23984.1223,
#  9728.37461904761,
#  13535.5,
#  2710.7500000000005,
#  30.0,
#  14989.78571457817,
#  8720.375,
#  2819.56336,
#  17489.875,
#  449.0,
#  87.99999999999999,
#  722.4192333333335,
#  2972.2243999999996,
#  202.75,
#  2431.45894,
#  2319.9999999999995,
#  5947.800599999999,
#  4421.19819,
#  197.94000000000003,
#  331.0,
#  20595.54579347143,
#  44.24999999999999,
#  32358.85735735736,
#  1034.05,
#  3688.73598,
#  2827.44221,
#  1158.0,
#  24752.625,
#  21059.0,
#  3924.6935999999996,
#  36332.93749999999,
#  61326.6875,
#  876.0,
#  3159.292,
#  28031.5,
#  1880.5,
#  3076.738755000001,
#  529.5,
#  21853.0,
#  11088.5,
#  627.60684,
#  4772.5,
#  3166.7500000000005,
#  32075.0,
#  2515.126933333333,
#  899.4125,
#  10296.987670000002,
#  7684.5792,
#  1890.3546399999998,
#  4138.683625000001,
#  268.0,
#  565.0,
#  29195.833333333336,
#  60863.750000000015,
#  8601.75,
#  9388.0,
#  546.37164,
#  1080.75,
#  2151.5,
#  201.87000000000003,
#  4248.4,
#  41000.74056666667,
#  1079.908,
#  790.395,
#  1865.4375,
#  21488.34572,
#  9191.5,
#  578.9889999999999,
#  2321.6041666666665,
#  4947.0,
#  42996.07462,
#  85263.875,
#  1086.4375,
#  2053.375,
#  532.9472174383111,
#  27087.78828,
#  12136.000000000002,
#  1324.8615999999997,
#  8551.5,
#  6288.32528,
#  1245.42688,
#  1611.5905214481338,
#  2019.0,
#  1540.375,
#  10583.650000000001,
#  2180.4,
#  9126.6,
#  42330.4872,
#  5829.890133333333,
#  22553.5312,
#  2563.75,
#  243.04166666666663,
#  1075.3749,
#  162.00000000000003,
#  731.1282400000001,
#  0.0,
#  3653.3298,
#  1518.0288199999998,
#  3433.4999999999995,
#  2896.150044,
#  16251.875,
#  667.8783333333332,
#  16150.000000000002,
#  18641.499999999996,
#  1362.875,
#  401.0,
#  5766.578142857143,
#  3533.361566666667,
#  7238.31768,
#  4995.193746666667,
#  1683.67636,
#  4004.0,
#  79666.5,
#  17971.36,
#  43980.5,
#  1780.9035066666668,
#  443.5,
#  1243.3124999999998,
#  18343.749999999996,
#  21.416666666666664,
#  398.0,
#  20774.455454545452,
#  89473.25,
#  605.875,
#  389.9951854734489,
#  11310.67964715129,
#  300.0,
#  5748.03225,
#  1342.102393333333,
#  1288.01779,
#  1407.3109500168862,
#  39200.80002499999,
#  54.25,
#  6812.64195,
#  8867.666666666668,
#  5750.999999999998,
#  2435.59729,
#  1046.9999999999998,
#  2898.81066,
#  1638.875,
#  2.0,
#  15020.0,
#  17441.02920000001,
#  64731.40137952364,
#  8269.458333333332,
#  3924.9942857142855,
#  23842.47466,
#  46048.75000000001,
#  118176.52279999998,
#  619.75,
#  831.5,
#  24394.999999999996,
#  1304.6500000000005,
#  1244.2709136382443,
#  942.075382857143,
#  13120.173333333336,
#  7090.0,
#  1989.9702213333333,
#  1085.0,
#  23140.587959999997,
#  6266.73328,
#  211.65,
#  371.31023999999996,
#  467.6548799999999,
#  2657.34508,
#  89653.99999999999,
#  5959.089248138,
#  4916.25,
#  44275.0,
#  68369.0336451172,
#  2093.24536,
#  2238.125,
#  204.3924033333333,
#  21774.0,
#  24060.0,
#  33681.3125,
#  310.00000000000006,
#  3408.24664,
#  718.0,
#  617.66134,
#  2984.75,
#  1673.4168,
#  1746.179883333333,
#  14819.5,
#  404.0076466666667,
#  709.5500000000001,
#  43185.36713982014,
#  2357.6027200000003,
#  912.3125,
#  408.9,
#  579.55625,
#  70375.39538350105,
#  3050.35,
#  12434.725920000003,
#  60454.59828,
#  26040.75,
#  4919.499999999999,
#  3500.8333333333335,
#  16919.5,
#  37730.988244999935,
#  86981.14285714286,
#  756.0,
#  13700.0,
#  31125.93160000005,
#  376.125,
#  898.5999999999999,
#  1644.75,
#  329.5,
#  11915.07142857143,
#  10287.682850000003,
#  2561.0000000000005,
#  8352.75,
#  1876.7500000000002,
#  1013.6249999999999,
#  10272.301875,
#  15461.857142857141,
#  1112.0,
#  87.78333333333333,
#  26868.000000000004,
#  3195.0,
#  18270.5,
#  286.25,
#  88194.3218,
#  1217.5716599999998,
#  906.2499999999999,
#  603.0000000000001,
#  5221.0,
#  14562.25,
#  54555.25,
#  2301.75,
#  2405.8125,
#  276.61368,
#  366.0,
#  13519.708333333332,
#  2965.244659999998,
#  48836.99999999999,
#  3695.3853599999998,
#  1489.0,
#  321.125,
#  4617.245187597222,
#  3722.4999999999995,
#  2225.0,
#  550.48125,
#  11287.833,
#  292.168952,
#  33078.43472,
#  53306.6875,
#  8362.6528,
#  1920.3749999999998,
#  3214.34256,
#  460.58132,
#  1238.625,
#  19418.0,
#  24730.0,
#  2547.0000000000005,
#  137.8125,
#  9343.49999999999,
#  2017.0000000000002,
#  15533.418012883649,
#  795.187467966811,
#  814.5,
#  28833.0,
#  2032.625,
#  41085.030399999996,
#  4256.75,
#  15495.13523734489,
#  21163.90498,
#  398.0702399999999,
#  1578.6666666666667,
#  599.4219216666665,
#  3550.0,
#  402.5,
#  1367.75,
#  54915.0,
#  568.0,
#  3051.5,
#  1604.459383,
#  528.7238399999999,
#  2614.5,
#  1149.4374999999998,
#  3001.0,
#  15311.0,
#  22016.500000000004,
#  46061.99999999999,
#  18346.999999999996,
#  20996.0,
#  1264.4141266666666,
#  446.22714666666667,
#  1821.4999999999998,
#  7337.0,
#  441.0,
#  13616.0,
#  8532.536359999998,
#  2426.3125,
#  None,
#  1879.821550000001,
#  52382.7,
#  16593.5,
#  5592.55,
#  1062.0874999999999,
#  32428.375,
#  378.3775,
#  10.0,
#  6118.125,
#  3665.93122,
#  19360.18746796681,
#  2366.9999999999995,
#  1018.122133333333,
#  482.71708,
#  3174.222716666666,
#  899.5,
#  1915.75,
#  19434.1875,
#  9864.75,
#  2395.0,
#  11276.11224,
#  4731.0,
#  36226.83333333332,
#  8979.999999999998,
#  1084.62035,
#  1714.9999999999998,
#  51127.96249999999,
#  1164.2338559999998,
#  519.23012,
#  15377.487520000002,
#  1006.5714285714284,
#  32572.000000000004,
#  16118.375,
#  3913.035714285714,
#  91741.74999999999,
#  3681.517146666666,
#  58511.21502,
#  71608.00000000001,
#  40130.875,
#  5038.0,
#  527.7,
#  5298.250000000001,
#  10512.333333333332,
#  3489.0,
#  516.0,
#  682.6781599999999,
#  1824.5000000000002,
#  578.5231,
#  11882.75,
#  18113.261477142853,
#  28227.3125,
#  2525.6666666666665,
#  29015.25,
#  1576.9999999999998,
#  45473.999,
#  40409.0,
#  3505.9999999999995,
#  15353.0,
#  2579.9999999999995,
#  864.75,
#  638.0416666666666,
#  2329.9034799999995,
#  38426.0,
#  1478.83522,
#  196.31184,
#  26148.1991,
#  27231.09,
#  5453.499999999999,
#  937.60128,
#  2658.9999999999995,
#  44.66666666666666,
#  3473.0,
#  35160.57736068437,
#  26489.8312,
#  160.31666666666666,
#  35879.0,
#  55559.07272000001,
#  1571.4089333333332,
#  13778.5,
#  436.0547933333333,
#  760.75,
#  3703.70884,
#  3846.0,
#  3291.875,
#  857.3125,
#  246.66666666666663,
#  522.0,
#  18563.8125,
#  None,
#  1327.2499999999998,
#  1347.0,
#  863.0,
#  52356.02017,
#  336.55,
#  2048.7306256137003,
#  46968.0,
#  322.00000000000006,
#  4606.18,
#  1450.875,
#  920.0,
#  25869.31999999999,
#  4190.75,
#  None,
#  21411.4375,
#  53346.00000000001,
#  13768.0,
#  51812.75,
#  46567.430239999994,
#  11145.59728,
#  1850.750000002009,
#  5422.38032,
#  873.0000000000001,
#  17944.719443333335,
#  18148.5,
#  910.1300000000002,
#  548.3990733333333,
#  1821.20882,
#  1013.6249999999997,
#  2236.8703333333333,
#  2794.9999999999995,
#  11151.999999999998,
#  25180.318279999996,
#  233.0,
#  461.875,
#  3928.6576289668114,
#  1865.5491666666665,
#  222.99999999999997,
#  None,
#  999.9999999999999,
#  1410.6220199999998,
#  2987.8715357857145,
#  768.0,
#  1593.1626800000001,
#  19127.0,
#  12605.55,
#  4164.750000000001,
#  965.49819,
#  29095.0,
#  13455.999999999998,
#  2324.9585199999997,
#  1243.5,
#  7984.24956,
#  1892.642106666677,
#  323.99999999999994,
#  286.1697916666667,
#  11197.75,
#  1685.2499999999998,
#  34833.0,
#  1025.36,
#  23370.5625,
#  4491.333333333333,
#  1581.75,
#  1757.8032,
#  29559.137322500002,
#  430.99999999999994,
#  39237.00000000001,
#  803.13006,
#  26266.999999999996,
#  272.103125,
#  38821.50000000001,
#  20174.0,
#  50734.875,
#  5624.39160000001,
#  13621.144960000001,
#  470.0,
#  10356.5,
#  2530.7,
#  528.625,
#  8616.5675,
#  4396.75,
#  22566.999999999996,
#  6337.75,
#  None,
#  804.11822964,
#  102.0,
#  4212.0,
#  649.55,
#  1614.6537399999995,
#  1843.870833333333,
#  42567.875,
#  54228.09128000001,
#  4587.000000000001,
#  38469.0,
#  4379.11204,
#  4134.25,
#  393.0,
#  30137.593606666665,
#  487.34999999999997,
#  312.9166666666667,
#  616.4929099999999,
#  2184.0,
#  264.9312000000002,
#  33811.7602,
#  80989.0002,
#  14938.0,
#  1303.0,
#  1436.0,
#  9882.0,
#  206.0,
#  26446.0,
#  1155.7186199999999,
#  350.4686533333333,
#  162.4375,
#  860.375,
#  419.125,
#  18947.999999999996,
#  2654.5,
#  25955.999999999993,
#  664.9996656009222,
#  12266.000000000002,
#  1196.25,
#  1227.5000000000002,
#  1608.49,
#  3748.25,
#  42736.86316,
#  3528.6428571428573,
#  54.75,
#  62766.03024000001,
#  2483.7500799999993,
#  1664.3749999999998,
#  1716.0,
#  31605.79359519,
#  1659.0,
#  61357.03064,
#  7654.51216,
#  17348.924426534,
#  24493.0,
#  1317.8333333333333,
#  1083.0105199999998,
#  46153.0,
#  2292.0,
#  406.0,
#  162.87559999999996,
#  31026.8125,
#  3031.5,
#  6274.75,
#  616.875,
#  1788.3333333333333,
#  3306.25,
#  5229.929285714291,
#  8274.0,
#  39634.0,
#  47919.199327800816,
#  409.3333333333333,
#  3535.25,
#  3200.5,
#  1469.3333333333335,
#  566.9265199999999,
#  4770.016639999999,
#  81087.6,
#  437.2916666666667,
#  4111.156249999999,
#  41236.37065999999,
#  1260.0,
#  380.0,
#  828.3125,
#  714.9831800000001,
#  5636.0,
#  33934.3125,
#  646.0,
#  383.37500000000006,
#  2558.0,
#  3215.5,
#  34173.0,
#  673.2500799999999,
#  32695.714285714286,
#  1533.0,
#  3258.375,
#  593.375,
#  2850.5,
#  3575.83534,
#  10367.5,
#  4661.749999999999,
#  253.77231999999995,
#  3510.0,
#  3607.0625,
#  3261.5,
#  41060.50000000001,
#  393.0,
#  6137.64232,
#  1882.0,
#  10298.003504999999,
#  780.6666666666667,
#  3503.329476190476,
#  801.0,
#  1112.1128,
#  3131.0,
#  8848.0,
#  450.99999999999994,
#  62072.31250000001,
#  895.5833333333334,
#  2054.05077,
#  660.0,
#  789.0,
#  25207.165631066622,
#  3194.2499999999995,
#  3700.915299999999,
#  492.5054,
#  155.0,
#  4904.0,
#  1493.9411,
#  41976.25,
#  811.0000000000001,
#  540.20128,
#  9448.5,
#  4996.22224,
#  880.17036,
#  630.7593999999999,
#  54204.00908,
#  373.0,
#  2420.375,
#  1346.0,
#  8961.25,
#  25217.068339999998,
#  2693.375,
#  7342.33174,
#  14265.4375,
#  7952.61198,
#  1090.100160000001,
#  3480.4583333333335,
#  None,
#  395.250941,
#  21873.649999999998,
#  1431.875,
#  820.8904,
#  2598.0,
#  21821.28,
#  26279.0,
#  444.5,
#  763.5,
#  4726.0,
#  540.6666666666666,
#  4479.0,
#  5455.0,
#  22779.066097009898,
#  1197.0,
#  3168.25432,
#  2135.75,
#  1970.1415200000004,
#  11609.67506,
#  1287.12,
#  2479.895,
#  1031.0,
#  326.33648,
#  34656.2306,
#  828.0,
#  1277.12952,
#  708.16296,
#  1114.4656,
#  10016.625,
#  131.0,
#  4256.357142857143,
#  2731.2801600000003,
#  1257.7,
#  53554.00000000001,
#  383.4428733333333,
#  450.75,
#  774.4166666666666,
#  9428.899999999998,
#  2418.25,
#  16674.375,
#  156.75,
#  1422.162897147,
#  6894.0,
#  1449.3866,
#  149.3746,
#  5909.25,
#  3059.5,
#  6509.000000000001,
#  0.0,
#  778.25,
#  1445.4999999999998,
#  1262.24528,
#  3452.5,
#  7966.499746796681,
#  26609.000000000004,
#  3136.0,
#  12615.999999999998,
#  3609.1022,
#  234.0,
#  26039.25,
#  28984.99279105466,
#  725.25,
#  2206.16672,
#  5196.772246500001,
#  1580.5,
#  3501.40097,
#  2618.82626,
#  959.3381,
#  581.0,
#  1903.35,
#  6145.49262,
#  688.5,
#  14160.6875,
#  368.31876,
#  63590.0,
#  7311.808,
#  2091.2499999999995,
#  8048.045332282842,
#  970.1972799999998,
#  18018.5,
#  1921.85255,
#  45725.54166666667,
#  686.5812599999999,
#  44213.75,
#  766.3639999999999,
#  41983.21284000001,
#  36627.99999999999,
#  403.99999999999994,
#  4544.0,
#  2002.88024,
#  10785.09604,
#  26840.0,
#  23097.7714,
#  191.99999999999997,
#  5177.0,
#  11559.999999999998,
#  4312.208333,
#  15395.34208,
#  1917.5357142857142,
#  1609.39214,
#  5287.331239999999,
#  1061.83644,
#  3356.85,
#  21034.440239999993,
#  20721.354166666664,
#  3038.25,
#  1979.125,
#  2079.25,
#  1267.35,
#  2322.8749999999995,
#  5383.43936,
#  1902.38059,
#  190.7499999999998,
#  34730.16927999999,
#  2992.3124999999995,
#  956.75,
#  628.5,
#  383.43071999999995,
#  34000.75,
#  284.042289,
#  10463.0,
#  2119.375,
#  7393.673107149115,
#  9741.97272,
#  14583.500000000004,
#  50207.15,
#  545.2546399999999,
#  615.3999999999997,
#  14181.94262,
#  334.2276063333333,
#  23668.09466999999,
#  27882.499999999996,
#  8059.114,
#  61093.9260648135,
#  25827.0,
#  27677.96495,
#  31662.682979999998,
#  3745.7201200020004,
#  12139.5,
#  91108.99692481387,
#  29665.000000000004,
#  26027.70663192488,
#  17363.09375,
#  34471.14285714286,
#  10021.9897,
#  16460.88533,
#  3204.3125,
#  102326.0,
#  4262.363400000001,
#  530.9999999999999,
#  2885.649687500048,
#  1406.25,
#  2379.2499999999995,
#  2468.91532,
#  1631.25,
#  814.0,
#  2104.0,
#  835.9999999999999,
#  8413.0,
#  762.7130799999999,
#  1948.2494166666668,
#  674.0,
#  2344.5000000000005,
#  39194.23872,
#  71121.22394,
#  2481.412320000001,
#  37937.83333333333,
#  756.75,
#  2157.0694399999998,
#  2377.5,
#  215.5,
#  479.0,
#  15611.71,
#  2678.157142857143,
#  1932.1875,
#  1112.1381666666666,
#  23124.25,
#  1008.3854000000002,
#  30230.0,
#  1227.5,
#  8527.996412282842,
#  2513.6385749999995,
#  330.00000000000006,
#  1287.3500000000001,
#  1629.50886,
#  3221.0,
#  1927.0,
#  1670.6659399999999,
#  406.07405,
#  9417.08336,
#  4883.0,
#  61770.6229564811,
#  14645.07142857143,
#  228.91666666666663,
#  22074.0,
#  8124.7621,
#  1288.9999999999998,
#  36778.0,
#  3097.5,
#  759.0774800000002,
#  18016.816,
#  2277.2499999999995,
#  3179.0000000000005,
#  21198.0,
#  3018.63528,
#  1290.0,
#  54768.460020000006,
#  16617.0,
#  2271.2886399999998,
#  197.32775916666665,
#  599.3906356017333,
#  28055.375,
#  2015.0,
#  7593.4375,
#  23119.999999999996,
#  9100.3125,
#  11216.75,
#  28416.63520021254,
#  138.0,
#  2758.12845,
#  215397.5,
#  609.3103999999998,
#  5741.0,
#  1469.9835147147146,
#  215.68233999999998,
#  7941.0176,
#  507.0,
#  3081.5,
#  647.32176,
#  42381.18992702479,
#  13411.124935933633,
#  9302.65419,
#  2181.9055406666666,
#  22472.799999999996,
#  2489.75,
#  25119.0,
#  1234.65,
#  ...]

# %%
print(re.search(r"\d+\.\d+\s*(end)?", " 70.9167endendendendendendendendendendend"))
# Out:
# <re.Match object; span=(1, 11), match='70.9167end'>

# %%
len(out_calories)
# Out:
# 7681

# %%
for i, x in enumerate(validation):
    x["gpt_ada_pred_1"] = out_calories[i]

write_csv(validation, data_path, "/open_ai_prediction_validation_test.csv")

# %%
validation[0]
# Out:
# {'prompt': '1 cup of rice-white-long-grain-regular-unenriched-cooked without salt, 3 cup of water-bottled-generic, 3 tablespoon of butter-without salt, 12 teaspoon of salt-table, 14 teaspoon of spices-pepper-black, 1 tablespoon of lemon juice-raw, 2 tablespoon of capers-canned, 2 tablespoon of parsley-fresh. Add rice to a large pan of boiling water. Cook over high heat about 15 minutes, until just tender. Watch carefully to prevent overcooking. Drain and rise thoroughly. Heat 1 tablespoon butter in a heavy skillet or pan over low heat. (I usually use same pan I used to cook the rice. ). Add rice, salt, and pepper. Heat, stirring gently with a fork. Stir in lemon juice, capers, and parsley and remove from heat. Stir in remaining butter and adjust seasonings to taste. Serve immediately.\n\n###\n\n',
#  'completion': ' 605.1250000000001 END',
#  'gpt_ada_pred_1': 765.375}

# %%
out_calories_amax = []

out_calories_amax = np.array(out_calories)
out_calories_amax[out_calories_amax==None] = 0
argmax_fail = np.argmax(out_calories_amax)
np.max

# %%
argmax_fail
# Out:
# 2698

# %%
out_calories[argmax_fail] #= 3400000.46768
# Out:
# 3400000.46768

# %%
validation[argmax_fail]
# Out:
# {'prompt': '1 pound of butter-without salt, 2 cup of sugars-granulated, 1 pinch of spices-cinnamon-ground, 1 tablespoon of water-bottled-generic, 34 cup of nuts-walnuts-english. Melt butter; add sugar, cinnamon and water. Bring to slow boil and boil 30 minutes, stirring constantly. Test in cold water for brittle test. Pour on cookie sheet and mark as soon as it sets. When chilled, dip each piece and dipping chocolate and ground nuts.\n\n###\n\n',
#  'completion': ' 30798.62904 END'}

# %%
get_calories(validation[argmax_fail]["prompt"], our_model)
# Out:
# 38863.37444

# %%
# max([x for x in out_calories[argmax_fail] if x is not None])

# %%
out_caloriesnp = np.array(out_calories)
nones = out_caloriesnp == None
out_caloriesnp = out_caloriesnp [~nones] # fix later

# %%
np.sum(nones)
# Out:
# 46

# %%
true_y = [ float(re.search(r"\d+\.\d+\s*(end)?", x["completion"])[0]) for x in validation]

# %%
true_y_cap = np.array(true_y)[~nones]

# %%
true_y_cap[true_y_cap == None]
# Out:
# array([], dtype=float64)

# %%
delta_test= out_caloriesnp - true_y_cap
print(delta_test.shape)
rmse_test = np.sqrt(np.mean((delta_test) ** 2))
rmae_test = np.sqrt(np.median((delta_test) ** 2))

rmse_test, rmae_test
# Out:
# (7635,)
# (5599.4410217903105, 243.00000000000045)

# %%
oh = plt.hist(true_y_cap, bins=100, density=False);
ph = plt.hist(out_caloriesnp, alpha=0.6, bins=100, density=False);
plt.xlim([-1000, 300000])
# Out:
# (-1000.0, 300000.0)

# %%
np.max(out_caloriesnp), np.max(true_y_cap)

old_max, old_pos = 3400000.46768, 2683 # Strange bug happened

# %%
np.argmax(out_caloriesnp)

out_caloriesnp
# Out:
# 2683

# %%
val2 = [ validation[i] for i in range(len(validation)) if not nones[i]]

# %%
val2[np.argmax(out_caloriesnp)]["prompt"],
# Out:
# ('1 pound of butter-without salt, 2 cup of sugars-granulated, 1 pinch of spices-cinnamon-ground, 1 tablespoon of water-bottled-generic, 34 cup of nuts-walnuts-english. Melt butter; add sugar, cinnamon and water. Bring to slow boil and boil 30 minutes, stirring constantly. Test in cold water for brittle test. Pour on cookie sheet and mark as soon as it sets. When chilled, dip each piece and dipping chocolate and ground nuts.\n\n###\n\n',)

# %%
out_caloriesnp [np.argmax(out_caloriesnp)] = get_calories(val2[np.argmax(out_caloriesnp)]["prompt"], our_model)

# %%
ph
# Out:
# (array([6.947e+03, 5.460e+02, 1.200e+02, 1.600e+01, 3.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([      0.       ,   34000.0046768,   68000.0093536,  102000.0140304,
#          136000.0187072,  170000.023384 ,  204000.0280608,  238000.0327376,
#          272000.0374144,  306000.0420912,  340000.046768 ,  374000.0514448,
#          408000.0561216,  442000.0607984,  476000.0654752,  510000.070152 ,
#          544000.0748288,  578000.0795056,  612000.0841824,  646000.0888592,
#          680000.093536 ,  714000.0982128,  748000.1028896,  782000.1075664,
#          816000.1122432,  850000.11692  ,  884000.1215968,  918000.1262736,
#          952000.1309504,  986000.1356272, 1020000.140304 , 1054000.1449808,
#         1088000.1496576, 1122000.1543344, 1156000.1590112, 1190000.163688 ,
#         1224000.1683648, 1258000.1730416, 1292000.1777184, 1326000.1823952,
#         1360000.187072 , 1394000.1917488, 1428000.1964256, 1462000.2011024,
#         1496000.2057792, 1530000.210456 , 1564000.2151328, 1598000.2198096,
#         1632000.2244864, 1666000.2291632, 1700000.23384  , 1734000.2385168,
#         1768000.2431936, 1802000.2478704, 1836000.2525472, 1870000.257224 ,
#         1904000.2619008, 1938000.2665776, 1972000.2712544, 2006000.2759312,
#         2040000.280608 , 2074000.2852848, 2108000.2899616, 2142000.2946384,
#         2176000.2993152, 2210000.303992 , 2244000.3086688, 2278000.3133456,
#         2312000.3180224, 2346000.3226992, 2380000.327376 , 2414000.3320528,
#         2448000.3367296, 2482000.3414064, 2516000.3460832, 2550000.35076  ,
#         2584000.3554368, 2618000.3601136, 2652000.3647904, 2686000.3694672,
#         2720000.374144 , 2754000.3788208, 2788000.3834976, 2822000.3881744,
#         2856000.3928512, 2890000.397528 , 2924000.4022048, 2958000.4068816,
#         2992000.4115584, 3026000.4162352, 3060000.420912 , 3094000.4255888,
#         3128000.4302656, 3162000.4349424, 3196000.4396192, 3230000.444296 ,
#         3264000.4489728, 3298000.4536496, 3332000.4583264, 3366000.4630032,
#         3400000.46768  ]),
#  <BarContainer object of 100 artists>)

# %%
validation[0]["prompt"]
# Out:
# '1 cup of rice-white-long-grain-regular-unenriched-cooked without salt, 3 cup of water-bottled-generic, 3 tablespoon of butter-without salt, 12 teaspoon of salt-table, 14 teaspoon of spices-pepper-black, 1 tablespoon of lemon juice-raw, 2 tablespoon of capers-canned, 2 tablespoon of parsley-fresh. Add rice to a large pan of boiling water. Cook over high heat about 15 minutes, until just tender. Watch carefully to prevent overcooking. Drain and rise thoroughly. Heat 1 tablespoon butter in a heavy skillet or pan over low heat. (I usually use same pan I used to cook the rice. ). Add rice, salt, and pepper. Heat, stirring gently with a fork. Stir in lemon juice, capers, and parsley and remove from heat. Stir in remaining butter and adjust seasonings to taste. Serve immediately.\n\n###\n\n'

# %%
#!openai tools fine_tunes.prepare_data -f ../data/open_ai_simple_prompts.csv
# Out:
# Analyzing...
#
# - Based on your file extension, your file is formatted as a CSV file
# - Your file contains 35867 prompt-completion pairs
# - There are 219 duplicated prompt-completion sets. These are rows: [1360, 1534, 5135, 5345, 6396, 6470, 6843, 7100, 7293, 7309, 7778, 8281, 9311, 9448, 9467, 9803, 9868, 10050, 10783, 10825, 11138, 11364, 11638, 11730, 11787, 12058, 12118, 12286, 12363, 12782, 13260, 13306, 13629, 13829, 13865, 13866, 14126, 14144, 14465, 14546, 14593, 14634, 14837, 15042, 15194, 15356, 15414, 15970, 16227, 16401, 16423, 16710, 16775, 16792, 16907, 17064, 17190, 17343, 17416, 17549, 17647, 17669, 17791, 17896, 18218, 18708, 18872, 19116, 19398, 19450, 19589, 19805, 19860, 20025, 20030, 20088, 20102, 20719, 21020, 21215, 21356, 21376, 21612, 21639, 21709, 21948, 21970, 21997, 22084, 22338, 22340, 22408, 22473, 22618, 22969, 23016, 23316, 23472, 23558, 23649, 23819, 23884, 23942, 24250, 24438, 24596, 24670, 25039, 25117, 25159, 25179, 25246, 25420, 25826, 25920, 26123, 26125, 26128, 26296, 26539, 26717, 26722, 26771, 26781, 26785, 26815, 26937, 27314, 27345, 27507, 27655, 27752, 27903, 28127, 28333, 28334, 28377, 28378, 28407, 28561, 28827, 28980, 29372, 29419, 29607, 29622, 29636, 29691, 29829, 29862, 29972, 29989, 30028, 30065, 30194, 30274, 30316, 30430, 30590, 30731, 30942, 31055, 31064, 31236, 31308, 31339, 31359, 31503, 31587, 31622, 31661, 31663, 31764, 31964, 32088, 32122, 32196, 32201, 32306, 32324, 32384, 32574, 32613, 32635, 32710, 32750, 32881, 33042, 33091, 33253, 33344, 33496, 33504, 33538, 33644, 33935, 34123, 34318, 34493, 34558, 34564, 34638, 34733, 34790, 35028, 35045, 35048, 35079, 35193, 35369, 35391, 35498, 35590, 35618, 35644, 35668, 35675, 35716, 35763]^C

# %%
# !export OPENAI_API_KEY="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"
# !openai api fine_tunes.create -t "../data/open_ai_simple_prompts_prepared.jsonl" -m ada
# Out:
# Error: No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://onboard.openai.com for details, or email support@openai.com if you have any questions.
